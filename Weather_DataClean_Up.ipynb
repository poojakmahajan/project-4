# %%
#Import Dependencies
import pandas as pd
import numpy as np
import datetime
from pathlib import Path

# %%
#import csv files
weather_df = pd.read_csv(Path('Resources/weather_features.csv'))
weather_df.head()
# Out:
#                       dt_iso city_name     temp  temp_min  temp_max  pressure  \
# 0  2015-01-01 00:00:00+01:00  Valencia  270.475   270.475   270.475      1001
# 1  2015-01-01 01:00:00+01:00  Valencia  270.475   270.475   270.475      1001
# 2  2015-01-01 02:00:00+01:00  Valencia  269.686   269.686   269.686      1002
# 3  2015-01-01 03:00:00+01:00  Valencia  269.686   269.686   269.686      1002
# 4  2015-01-01 04:00:00+01:00  Valencia  269.686   269.686   269.686      1002
#
#    humidity  wind_speed  wind_deg  rain_1h  rain_3h  snow_3h  clouds_all  \
# 0        77           1        62      0.0      0.0      0.0           0
# 1        77           1        62      0.0      0.0      0.0           0
# 2        78           0        23      0.0      0.0      0.0           0
# 3        78           0        23      0.0      0.0      0.0           0
# 4        78           0        23      0.0      0.0      0.0           0
#
# ...

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178396 entries, 0 to 178395
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dt_iso               178396 non-null  object
#  1   city_name            178396 non-null  object
#  2   temp                 178396 non-null  float64
#  3   temp_min             178396 non-null  float64
#  4   temp_max             178396 non-null  float64
#  5   pressure             178396 non-null  int64
#  6   humidity             178396 non-null  int64
#  7   wind_speed           178396 non-null  int64
#  8   wind_deg             178396 non-null  int64
#  9   rain_1h              178396 non-null  float64
#  10  rain_3h              178396 non-null  float64
#  11  snow_3h              178396 non-null  float64
#  12  clouds_all           178396 non-null  int64
#  13  weather_id           178396 non-null  int64
#  14  weather_main         178396 non-null  object
# ...

# %%
#find which columns have null values
for column in weather_df.columns:
    print(f"Column {column} has {weather_df[column].isnull().sum()} null values")
# Out:
# Column dt_iso has 0 null values
# Column city_name has 0 null values
# Column temp has 0 null values
# Column temp_min has 0 null values
# Column temp_max has 0 null values
# Column pressure has 0 null values
# Column humidity has 0 null values
# Column wind_speed has 0 null values
# Column wind_deg has 0 null values
# Column rain_1h has 0 null values
# Column rain_3h has 0 null values
# Column snow_3h has 0 null values
# Column clouds_all has 0 null values
# Column weather_id has 0 null values
# Column weather_main has 0 null values
# Column weather_description has 0 null values
# Column weather_icon has 0 null values

# %%
#split dt_iso column to convert to date_time
dt = weather_df['dt_iso']
weather_df[['date_time','delete_col']] =  dt.str.split("+", n=1, expand=True)
weather_df
# Out:
#                            dt_iso city_name     temp  temp_min  temp_max  \
# 0       2015-01-01 00:00:00+01:00  Valencia  270.475   270.475   270.475
# 1       2015-01-01 01:00:00+01:00  Valencia  270.475   270.475   270.475
# 2       2015-01-01 02:00:00+01:00  Valencia  269.686   269.686   269.686
# 3       2015-01-01 03:00:00+01:00  Valencia  269.686   269.686   269.686
# 4       2015-01-01 04:00:00+01:00  Valencia  269.686   269.686   269.686
# ...                           ...       ...      ...       ...       ...
# 178391  2018-12-31 19:00:00+01:00   Seville  287.760   287.150   288.150
# 178392  2018-12-31 20:00:00+01:00   Seville  285.760   285.150   286.150
# 178393  2018-12-31 21:00:00+01:00   Seville  285.150   285.150   285.150
# 178394  2018-12-31 22:00:00+01:00   Seville  284.150   284.150   284.150
# 178395  2018-12-31 23:00:00+01:00   Seville  283.970   282.150   285.150
#
#         pressure  humidity  wind_speed  wind_deg  rain_1h  rain_3h  snow_3h  \
# ...

# %%
#drop unwanted columns
weather_df = weather_df.drop(["weather_id", "weather_icon", "delete_col", "dt_iso"], axis=1)
weather_df.head()
# Out:
#   city_name     temp  temp_min  temp_max  pressure  humidity  wind_speed  \
# 0  Valencia  270.475   270.475   270.475      1001        77           1
# 1  Valencia  270.475   270.475   270.475      1001        77           1
# 2  Valencia  269.686   269.686   269.686      1002        78           0
# 3  Valencia  269.686   269.686   269.686      1002        78           0
# 4  Valencia  269.686   269.686   269.686      1002        78           0
#
#    wind_deg  rain_1h  rain_3h  snow_3h  clouds_all weather_main  \
# 0        62      0.0      0.0      0.0           0        clear
# 1        62      0.0      0.0      0.0           0        clear
# 2        23      0.0      0.0      0.0           0        clear
# 3        23      0.0      0.0      0.0           0        clear
# 4        23      0.0      0.0      0.0           0        clear
#
#   weather_description            date_time
# 0        sky is clear  2015-01-01 00:00:00
# 1        sky is clear  2015-01-01 01:00:00
# ...

# %% [markdown]
# #Create a Postgres Database connection

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:postgres@localhost:5432/energyconsumptiondb')
connection = engine.connect()

# %% [markdown]
# ## Create Table for weather data in Postgres db energyconsumptiondb

# %%
weather_df.to_sql(name="weatherbyhour", con=engine, if_exists="append", index=False)

# %%
pd.read_sql_query('select* from public.weatherbyhour', con=engine).head()
# Out:
#   city_name     temp  temp_min  temp_max  pressure  humidity  wind_speed  \
# 0  Valencia  270.475   270.475   270.475      1001        77           1
# 1  Valencia  270.475   270.475   270.475      1001        77           1
# 2  Valencia  269.686   269.686   269.686      1002        78           0
# 3  Valencia  269.686   269.686   269.686      1002        78           0
# 4  Valencia  269.686   269.686   269.686      1002        78           0
#
#    wind_deg  rain_1h  rain_3h  snow_3h  clouds_all weather_main  \
# 0        62      0.0      0.0      0.0           0        clear
# 1        62      0.0      0.0      0.0           0        clear
# 2        23      0.0      0.0      0.0           0        clear
# 3        23      0.0      0.0      0.0           0        clear
# 4        23      0.0      0.0      0.0           0        clear
#
#   weather_description            date_time
# 0        sky is clear  2015-01-01 00:00:00
# 1        sky is clear  2015-01-01 01:00:00
# ...

# %%
pd.read_sql_query('select count(*) from public.weatherbyhour', con=engine).head()
# Out:
#     count
# 0  178396
